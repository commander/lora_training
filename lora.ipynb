# %%
import sys

# %%
print(sys.version)
print(sys.executable)
# Out:
# 3.10.13 (main, Nov 21 2025, 12:53:12) [Clang 17.0.0 (clang-1700.0.13.5)]
# /Users/ashishsheth/Documents/personal/repos/lora/.venv/bin/python

# %%
# # %pip install --upgrade pip
# %pip install --disable-pip-version-check \
#     torch \
#     torchdata --quiet

# %pip install \
#     transformers \
#     datasets \
#     evaluate \
#     rouge_score \
#     loralib \
#     peft --quiet

# %%
# from datasets import load_dataset
# from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, GenerationConfig, TrainingArguments, Trainer
# import torch
# import time
# import evaluate
# import pandas as pd
# import numpy as np

# %%
# %pip install datasets
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 get_ipython().run_line_magic('pip', 'install datasets')
#
# File ~/Documents/personal/repos/lora/.venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2482, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2480     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2481 with self.builtin_trap:
# -> 2482     result = fn(*args, **kwargs)
#    2484 # The code below prevents the output from being displayed
#    2485 # when using magics with decorator @output_can_be_silenced
#    2486 # when the last Python token in the expression is a ';'.
#    2487 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Documents/personal/repos/lora/.venv/lib/python3.10/site-packages/IPython/core/magics/packaging.py:105, in pip(self, line)
#
# File ~/Documents/personal/repos/lora/.venv/lib/python3.10/site-packages/ipykernel/zmqshell.py:788, in system_piped(self, cmd)
#
# File ~/Documents/personal/repos/lora/.venv/lib/python3.10/site-packages/IPython/utils/_process_posix.py:125, in system(self, cmd)
#
# ModuleNotFoundError: No module named 'pexpect'
